# %% [markdown]
# <a href="https://colab.research.google.com/github/ArpitaRPatki/NLP-LAB/blob/main/NLP_LAB_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "India is a country known for its rich culture and traditions. It has diverse languages, religions, festivals, and customs. People in India celebrate festivals like Diwali, Holi, and Eid with great joy. Respect for elders, family values, and unity in diversity are important aspects of Indian culture."

print(text)
# Out:
# India is a country known for its rich culture and traditions. It has diverse languages, religions, festivals, and customs. People in India celebrate festivals like Diwali, Holi, and Eid with great joy. Respect for elders, family values, and unity in diversity are important aspects of Indian culture.

# %% [markdown]
# **Assignment 1 **
#
# 1. lowercase the given text .
# 2. Tokenisation of text using nltk
# 3. Remove the words that are not adding much meaninf i.e  is , the ..stopword ,there is library which have all such wwrds for eng language.
# 4. stemming and lemminisation

# %%
text = text.lower()
print(text)
# Out:
# india is a country known for its rich culture and traditions. it has diverse languages, religions, festivals, and customs. people in india celebrate festivals like diwali, holi, and eid with great joy. respect for elders, family values, and unity in diversity are important aspects of indian culture.

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['india', 'is', 'a', 'country', 'known', 'for', 'its', 'rich', 'culture', 'and', 'traditions', '.', 'it', 'has', 'diverse', 'languages', ',', 'religions', ',', 'festivals', ',', 'and', 'customs', '.', 'people', 'in', 'india', 'celebrate', 'festivals', 'like', 'diwali', ',', 'holi', ',', 'and', 'eid', 'with', 'great', 'joy', '.', 'respect', 'for', 'elders', ',', 'family', 'values', ',', 'and', 'unity', 'in', 'diversity', 'are', 'important', 'aspects', 'of', 'indian', 'culture', '.']

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

filtered_tokens = [word for word in tokens if word not in stop_words]
print(filtered_tokens)
# Out:
# ['india', 'country', 'known', 'rich', 'culture', 'traditions', '.', 'diverse', 'languages', ',', 'religions', ',', 'festivals', ',', 'customs', '.', 'people', 'india', 'celebrate', 'festivals', 'like', 'diwali', ',', 'holi', ',', 'eid', 'great', 'joy', '.', 'respect', 'elders', ',', 'family', 'values', ',', 'unity', 'diversity', 'important', 'aspects', 'indian', 'culture', '.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in filtered_tokens]
print(stemmed_words)
# Out:
# ['india', 'countri', 'known', 'rich', 'cultur', 'tradit', '.', 'divers', 'languag', ',', 'religion', ',', 'festiv', ',', 'custom', '.', 'peopl', 'india', 'celebr', 'festiv', 'like', 'diwali', ',', 'holi', ',', 'eid', 'great', 'joy', '.', 'respect', 'elder', ',', 'famili', 'valu', ',', 'uniti', 'divers', 'import', 'aspect', 'indian', 'cultur', '.']

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print(lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ['india', 'country', 'known', 'rich', 'culture', 'tradition', '.', 'diverse', 'language', ',', 'religion', ',', 'festival', ',', 'custom', '.', 'people', 'india', 'celebrate', 'festival', 'like', 'diwali', ',', 'holi', ',', 'eid', 'great', 'joy', '.', 'respect', 'elder', ',', 'family', 'value', ',', 'unity', 'diversity', 'important', 'aspect', 'indian', 'culture', '.']

# %%
from nltk.tokenize import word_tokenize
import string

tokens = word_tokenize(text)

clean_tokens = [word for word in tokens if word not in string.punctuation]

print(clean_tokens)
# Out:
# ['india', 'is', 'a', 'country', 'known', 'for', 'its', 'rich', 'culture', 'and', 'traditions', 'it', 'has', 'diverse', 'languages', 'religions', 'festivals', 'and', 'customs', 'people', 'in', 'india', 'celebrate', 'festivals', 'like', 'diwali', 'holi', 'and', 'eid', 'with', 'great', 'joy', 'respect', 'for', 'elders', 'family', 'values', 'and', 'unity', 'in', 'diversity', 'are', 'important', 'aspects', 'of', 'indian', 'culture']

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
clean_text = " ".join(clean_tokens)
print(clean_text)
# Out:
# india is a country known for its rich culture and traditions it has diverse languages religions festivals and customs people in india celebrate festivals like diwali holi and eid with great joy respect for elders family values and unity in diversity are important aspects of indian culture

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(clean_text)

for token in doc:
    print(token.text, token.pos_)
# Out:
# india PROPN
# is AUX
# a DET
# country NOUN
# known VERB
# for ADP
# its PRON
# rich ADJ
# culture NOUN
# and CCONJ
# traditions NOUN
# it PRON
# has VERB
# diverse ADJ
# languages NOUN
# religions NOUN
# festivals NOUN
# and CCONJ
# customs NOUN
# people NOUN
# in ADP
# india PROPN
# celebrate VERB
# festivals NOUN
# like ADP
# diwali PROPN
# holi PROPN
# and CCONJ
# eid PROPN
# with ADP
# great ADJ
# joy NOUN
# respect NOUN
# for ADP
# elders NOUN
# family NOUN
# values NOUN
# and CCONJ
# unity NOUN
# in ADP
# diversity NOUN
# are AUX
# important ADJ
# aspects NOUN
# of ADP
# indian ADJ
# culture NOUN
